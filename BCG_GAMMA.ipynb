# %% [markdown]
# <a href="https://colab.research.google.com/github/Daisyshi84/BCG_Gamma/blob/main/BCG_GAMMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import packages

# %% [markdown]
# 1. Loading data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import pickle
# %matplotlib inline
sns.set(color_codes=True)

# %%
#Set maximum number of columns to be displayed
pd.set_option('display.max_columns',100)

# %%
#load data
train_data = pd.read_csv("/content/drive/MyDrive/BCG/ml_case_training_data (1).csv") 
churn_data = pd.read_csv("/content/drive/MyDrive/BCG/ml_case_training_output.csv") 
history_data = pd.read_csv("/content/drive/MyDrive/BCG/ml_case_training_hist_data (1).csv") 

train_data.head()
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
# 2                NaN                               NaN      4660
# 3                NaN  foosdfpfkusacimwkcsosbicdxkicaua       544
# 4                NaN  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#    cons_gas_12m  cons_last_month  date_activ    date_end date_first_activ  \
# 0             0            10025  2012-11-07  2016-11-06              NaN
# ...

# %%
train_data.head()
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
# 2                NaN                               NaN      4660
# 3                NaN  foosdfpfkusacimwkcsosbicdxkicaua       544
# 4                NaN  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#    cons_gas_12m  cons_last_month  date_activ    date_end date_first_activ  \
# 0             0            10025  2012-11-07  2016-11-06              NaN
# ...

# %%
churn_data.head()
# Out:
#                                  id  churn
# 0  48ada52261e7cf58715202705a0451c9      0
# 1  24011ae4ebbe3035111d65fa7c15bc57      1
# 2  d29c2c54acc38ff3c0614d0a653813dd      0
# 3  764c75f661154dac3a6c254cd082ea7d      0
# 4  bba03439a292a1e166f80264c16191cb      0

# %% [markdown]
# Combining two dataframes

# %%
train = pd.merge(train_data,churn_data, on = 'id')

# %% [markdown]
# 2. General statistics of a dataframe

# %%
pd.DataFrame({"Data type":train.dtypes})
# Out:
#                          Data type
# id                          object
# activity_new                object
# campaign_disc_ele          float64
# channel_sales               object
# cons_12m                     int64
# cons_gas_12m                 int64
# cons_last_month              int64
# date_activ                  object
# date_end                    object
# date_first_activ            object
# date_modif_prod             object
# date_renewal                object
# forecast_base_bill_ele     float64
# forecast_base_bill_year    float64
# forecast_bill_12m          float64
# forecast_cons              float64
# forecast_cons_12m          float64
# forecast_cons_year           int64
# forecast_discount_energy   float64
# forecast_meter_rent_12m    float64
# forecast_price_energy_p1   float64
# forecast_price_energy_p2   float64
# forecast_price_pow_p1      float64
# has_gas                     object
# imp_cons                   float64
# margin_gross_pow_ele       float64
# ...

# %%
pd.DataFrame({"Data Type":history_data.dtypes})
# Out:
#       Data Type
# id       object
# churn     int64

# %% [markdown]
# Dataframe statistics: Let's also look at the basic statistics of the data

# %%
train.describe()
# Out:
#        campaign_disc_ele      cons_12m  cons_gas_12m  cons_last_month  \
# count                0.0  1.609600e+04  1.609600e+04     1.609600e+04
# mean                 NaN  1.948044e+05  3.191164e+04     1.946154e+04
# std                  NaN  6.795151e+05  1.775885e+05     8.235676e+04
# min                  NaN -1.252760e+05 -3.037000e+03    -9.138600e+04
# 25%                  NaN  5.906250e+03  0.000000e+00     0.000000e+00
# 50%                  NaN  1.533250e+04  0.000000e+00     9.010000e+02
# 75%                  NaN  5.022150e+04  0.000000e+00     4.127000e+03
# max                  NaN  1.609711e+07  4.188440e+06     4.538720e+06
#
#        forecast_base_bill_ele  forecast_base_bill_year  forecast_bill_12m  \
# count             3508.000000              3508.000000        3508.000000
# mean               335.843857               335.843857        3837.441866
# std                649.406000               649.406000        5425.744327
# ...

# %%
missing=pd.DataFrame({"missing in %":round(train_data.isnull().sum()/len(train_data*100),2)})
missing
# Out:
#                           missing in %
# id                                0.00
# activity_new                      0.59
# campaign_disc_ele                 1.00
# channel_sales                     0.26
# cons_12m                          0.00
# cons_gas_12m                      0.00
# cons_last_month                   0.00
# date_activ                        0.00
# date_end                          0.00
# date_first_activ                  0.78
# date_modif_prod                   0.01
# date_renewal                      0.00
# forecast_base_bill_ele            0.78
# forecast_base_bill_year           0.78
# forecast_bill_12m                 0.78
# forecast_cons                     0.78
# forecast_cons_12m                 0.00
# forecast_cons_year                0.00
# forecast_discount_energy          0.01
# forecast_meter_rent_12m           0.00
# forecast_price_energy_p1          0.01
# forecast_price_energy_p2          0.01
# forecast_price_pow_p1             0.01
# ...

# %%
churn_data[churn_data['churn']==0].count()/churn_data[churn_data['churn']==1].count()
# Out:
# id       9.091536
# churn    9.091536
# dtype: float64
